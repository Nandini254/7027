# %%
a=5
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 2
# 125
# 1

# %%
P=input("enter the value of P")
t=input("enter the value of t")
r=input("enter the value of r")
I=float(P)*float(t)*float(r)
print(I)
# Out:
# enter the value of P5
# enter the value of t4
# enter the value of r3
# 60.0

# %%
r=input("enter the value of r")
pi=3.14
A=pi*float(r)*float(r)
print(A)
# Out:
# enter the value of r4
# 50.24

# %%
h=input("enter the value of h")
b=input("enter the value of b")
A=(float(h)*float(b))/2
print(A)
# Out:
# enter the value of h3
# enter the value of b6
# 9.0

# %%
celsius=input("enter the value of celsius")
fahrenheit=(float(celsius)*1.8)+32
print(fahrenheit)
# Out:
# enter the value of celsius6
# 42.8

# %%
l=input("enter the value of l")
h=input("enter the value of b")
A=float(l)*float(b)
print(A)
# Out:
# enter the value of l3
# enter the value of b2
# 18.0

# %%
a=input ("enter the value of a")
P=4*float(a)
print(P)
# Out:
# enter the value of a3
# 12.0

# %%
r=input("enter the value of r")
pi=3.14
C=2*pi*float(r)
print(C)
# Out:
# enter the value of r2
# 12.56

# %%
x=int(input("enter the value of x"))
y=int(input("enter the value of y"))
temp,x=x,y
y=temp
print(x,y)
# Out:
# enter the value of x6
# enter the value of y5
# 5 6
